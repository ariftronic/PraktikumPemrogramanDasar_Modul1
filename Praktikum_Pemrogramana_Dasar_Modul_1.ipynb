# %% [markdown]
# <a href="https://colab.research.google.com/github/ariftronic/PraktikumPemrogramanDasar_Modul1/blob/main/Praktikum_Pemrogramana_Dasar_Modul_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MODUL 1 Introduction to Python Programming

# %% [markdown]
# Membuat Program Python untuk Meminta pengguna memasukkan nama dan umur.

# %%
nama = input("Masukan Nama :")
umur = int(input("Masukan Umur :"))

print ("Nama :" , nama)
print ("Umur :" , umur)
# Out:
# Masukan Nama :Muhammad Nur Arif
# Masukan Umur :19
# Nama : Muhammad Nur Arif
# Umur : 19

# %% [markdown]
# Penjelasan Secara Singkat Hasil dari Ujicoba
#
# Baris 1 : fungsi input(), adalah fungsi untuk memasukan input lewat terminal ,data akan menghasilkan teks(string)
#
# Baris 2 : fungsi input(), adalah fungsi untuk memasukkan input lewat terminal, data akan diconversi dari teks ke string (intenger) lalu disimpan ke variabel
#
# Baris 4 : Fungsi untuk mencetak teks “Nama :”, lalu diikuti nilai dari variabel nama
#
# Baris 5 : Fungsi untuk mencetak teks “Umur:”, lalu diikuti nilai dari variabel umur

# %% [markdown]
# Membuat Program Python untuk menampilkan sapaan personal.

# %%
nama = input("Masukan Nama :")
print(f"Hai {nama} Selamat Datang di Praktikum Pemrograman 1")
# Out:
# Masukan Nama :Muhammad Nur Arif
# Hai Muhammad Nur Arif Selamat Datang di Praktikum Pemrograman 1

# %% [markdown]
# Baris 1 : Menampilkan "Masukan Nama :", di layar dan meminta pengguna menginput nama, input disimpan dalam variabel sebagai string
#
# Baris 2 : Menampilkan Teks ke layar, dengan format f-string , variabel nama akan berisi nilai yang tersimpan

# %% [markdown]
# Membuat Program untuk Menghitung tahun lahir pengguna (dari umur).

# %%
umur_string = input("Masukkan Umur Anda : ")
umur_int = int(umur_string)
tahun_sekarang = 2026
tahun_lahir = tahun_sekarang - umur_int
print(f"Jika umur anda {umur_int} tahun, tahun kelahiran anda {tahun_lahir}")
# Out:
# Masukkan Umur Anda : 19
# Jika umur anda 19 tahun, tahun kelahiran anda 2007

# %% [markdown]
# Baris 1 : Membuat fungsi input untuk meminta pengguna menginput umur di terminal, variabel yang disimpan adalah berbentuk string
#
# Baris 2 : Mengonversi Teks dari umur string, menjadi umur integer dan disimpan di umur_int
#
# Baris 3 : Menentukan nilai variabel yaitu tahun saat ini
#
# Baris 4 : Membuat Rumus untuk menghitung tahun lahir, didapat dari tahun sekarang dikurangi dengan umur_int/input pengguna
#
# Baris 5 : Menampilkan (Print) hasil perhitungan menggunakan f-string, dan menyisipkan variabel ditengahnya
